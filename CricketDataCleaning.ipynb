# %% [markdown]
# # Data Cleaning
# Data Source: https://www.espncricinfo.com/records/highest-career-batting-average-282910

# %%
import pandas as pd

# %%
# Load the Cricket Test Match dataset
df = pd.read_csv('/content/CricketData.csv')

# %%
df
# Out:
#                         Player       Span  Mat  Inns  NO  Runs    HS    Ave  \
# 0             DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94
# 1             PHKD Mendis (SL)  2022-2025   14    24   3  1316  182*  62.66
# 2               AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87
# 3              RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97
# 4              GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83
# ..                         ...        ...  ...   ...  ..   ...   ...    ...
# 59           GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25
# 60           WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22
# 61             SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21
# 62  Hashmatullah Shahidi (AFG)  2018-2025   11    21   5   771   246  48.18
# 63            DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00
#
#        BF     SR  100  50     0    4s  6s
# 0   9800+  58.60   29  13   7.0  626+   6
# 1    2063  63.79    5   5   NaN   137  24
# 2    2667  55.68    5   4   2.0   186   5
# 3   1707+  54.48    7  11   1.0  246+  11
# 4    416+  56.00   10   5   2.0  104+   1
# ..    ...    ...  ...  ..   ...   ...  ..
# 59  15525  59.67   27  38  11.0  1165  24
# 60  3118+  44.77    7   6   1.0  119+   0
# 61  3217+  60.02    6  13   4.0  241+  5+
# 62   1629  47.32    2   2   NaN    87   1
# 63  2110+  25.59    1  10   2.0   53+   0
#
# [64 rows x 15 columns]

# %%
# Rename columns to more descriptive names for better readability
df = df.rename(columns = {'Span':'Playing_Span','Mat':'Matches_Played',
                          'Inns' : 'Innings_Batted','NO':'Not_Outs',
                          'Runs':'Runs_Scored','HS':'Highest_Inns_Score',
                          'Ave':'Batting_Average', 'BF':'Balls_Faced',
                          'SR':'Batting_Strike_Rate', '100':'Hundreds_Scored',
                          '50':'Fifties_Scored', '0':'Ducks_Scored',
                          '4s':'Boundary_Fours','6s':'Boundary_Sixes'})

# %%
df.head()
# Out:
#              Player Playing_Span  Matches_Played  Innings_Batted  Not_Outs  \
# 0  DG Bradman (AUS)    1928-1948              52              80        10
# 1  PHKD Mendis (SL)    2022-2025              14              24         3
# 2    AC Voges (AUS)    2015-2016              20              31         7
# 3   RG Pollock (SA)    1963-1970              23              41         4
# 4   GA Headley (WI)    1930-1954              22              40         4
#
#    Runs_Scored Highest_Inns_Score  Batting_Average Balls_Faced  \
# 0         6996                334            99.94       9800+
# 1         1316               182*            62.66        2063
# 2         1485               269*            61.87        2667
# 3         2256                274            60.97       1707+
# 4         2190               270*            60.83        416+
#
#    Batting_Strike_Rate  Hundreds_Scored  Fifties_Scored  Ducks_Scored  \
# 0                58.60               29              13           7.0
# 1                63.79                5               5           NaN
# 2                55.68                5               4           2.0
# 3                54.48                7              11           1.0
# 4                56.00               10               5           2.0
#
#   Boundary_Fours Boundary_Sixes
# 0           626+              6
# 1            137             24
# 2            186              5
# 3           246+             11
# 4           104+              1

# %%
# Identify columns with missing values
df.isnull().any()
# Out:
# Player                 False
# Playing_Span           False
# Matches_Played         False
# Innings_Batted         False
# Not_Outs               False
# Runs_Scored            False
# Highest_Inns_Score     False
# Batting_Average        False
# Balls_Faced             True
# Batting_Strike_Rate     True
# Hundreds_Scored        False
# Fifties_Scored         False
# Ducks_Scored            True
# Boundary_Fours         False
# Boundary_Sixes         False
# dtype: bool

# %%
# Check specific columns for null values to decide on cleaning strategy
df[df['Balls_Faced'].isna()==1]
# Out:
#                   Player Playing_Span  Matches_Played  Innings_Batted  \
# 8         ED Weekes (WI)    1948-1958              48              81
# 13       CL Walcott (WI)    1948-1960              44              74
# 54  Hon.FS Jackson (ENG)    1893-1905              20              33
#
#     Not_Outs  Runs_Scored Highest_Inns_Score  Batting_Average Balls_Faced  \
# 8          5         4455                207            58.61         NaN
# 13         7         3798                220            56.68         NaN
# 54         4         1415               144*            48.79         NaN
#
#     Batting_Strike_Rate  Hundreds_Scored  Fifties_Scored  Ducks_Scored  \
# 8                   NaN               15              19           6.0
# 13                  NaN               15              14           1.0
# 54                  NaN                5               6           3.0
#
#    Boundary_Fours Boundary_Sixes
# 8            258+              2
# 13           107+             11
# 54            51+              0

# %%
df[df['Batting_Strike_Rate'].isna()==1]
# Out:
#                   Player Playing_Span  Matches_Played  Innings_Batted  \
# 8         ED Weekes (WI)    1948-1958              48              81
# 13       CL Walcott (WI)    1948-1960              44              74
# 54  Hon.FS Jackson (ENG)    1893-1905              20              33
#
#     Not_Outs  Runs_Scored Highest_Inns_Score  Batting_Average Balls_Faced  \
# 8          5         4455                207            58.61         NaN
# 13         7         3798                220            56.68         NaN
# 54         4         1415               144*            48.79         NaN
#
#     Batting_Strike_Rate  Hundreds_Scored  Fifties_Scored  Ducks_Scored  \
# 8                   NaN               15              19           6.0
# 13                  NaN               15              14           1.0
# 54                  NaN                5               6           3.0
#
#    Boundary_Fours Boundary_Sixes
# 8            258+              2
# 13           107+             11
# 54            51+              0

# %%
df[df['Ducks_Scored'].isna()==1]
# Out:
#                         Player Playing_Span  Matches_Played  Innings_Batted  \
# 1             PHKD Mendis (SL)    2022-2025              14              24
# 62  Hashmatullah Shahidi (AFG)    2018-2025              11              21
#
#     Not_Outs  Runs_Scored Highest_Inns_Score  Batting_Average Balls_Faced  \
# 1          3         1316               182*            62.66        2063
# 62         5          771                246            48.18        1629
#
#     Batting_Strike_Rate  Hundreds_Scored  Fifties_Scored  Ducks_Scored  \
# 1                 63.79                5               5           NaN
# 62                47.32                2               2           NaN
#
#    Boundary_Fours Boundary_Sixes
# 1             137             24
# 62             87              1

# %%
# Fill missing numerical values with 0 to maintain data integrity
df['Balls_Faced']=df['Balls_Faced'].fillna(0)
df['Batting_Strike_Rate'] = df['Batting_Strike_Rate'].fillna(0)
df['Ducks_Scored'] = df['Ducks_Scored'].fillna(0)

# %%
# Verify that all nulls in critical columns have been addressed
df.isnull().sum()
# Out:
# Player                 0
# Playing_Span           0
# Matches_Played         0
# Innings_Batted         0
# Not_Outs               0
# Runs_Scored            0
# Highest_Inns_Score     0
# Batting_Average        0
# Balls_Faced            0
# Batting_Strike_Rate    0
# Hundreds_Scored        0
# Fifties_Scored         0
# Ducks_Scored           0
# Boundary_Fours         0
# Boundary_Sixes         0
# dtype: int64

# %%
# Identify and remove duplicate player records
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 59    False
# 60    False
# 61    False
# 62    False
# 63     True
# Length: 64, dtype: bool

# %%
df[df['Player'].duplicated()==1]
# Out:
#                Player Playing_Span  Matches_Played  Innings_Batted  Not_Outs  \
# 49  YBK Jaiswal (IND)    2023-2025              28              53         2
# 63   DR Jardine (ENG)    1928-1934              22              33         6
#
#     Runs_Scored Highest_Inns_Score  Batting_Average Balls_Faced  \
# 49         2511               214*            49.23        3803
# 63         1296                127            48.00       2110+
#
#     Batting_Strike_Rate  Hundreds_Scored  Fifties_Scored  Ducks_Scored  \
# 49                66.02                7              13           6.0
# 63                25.59                1              10           2.0
#
#    Boundary_Fours Boundary_Sixes
# 49            312             45
# 63            53+              0

# %%
df[df['Player'].isin(['YBK Jaiswal (IND)','DR Jardine (ENG)'])]
# Out:
#                Player Playing_Span  Matches_Played  Innings_Batted  Not_Outs  \
# 46  YBK Jaiswal (IND)    2023-2025              28              53         2
# 49  YBK Jaiswal (IND)    2023-2025              28              53         2
# 58   DR Jardine (ENG)    1928-1934              22              33         6
# 63   DR Jardine (ENG)    1928-1934              22              33         6
#
#     Runs_Scored Highest_Inns_Score  Batting_Average Balls_Faced  \
# 46         2511               214*            49.23        3803
# 49         2511               214*            49.23        3803
# 58         1296                127            48.00       2110+
# 63         1296                127            48.00       2110+
#
#     Batting_Strike_Rate  Hundreds_Scored  Fifties_Scored  Ducks_Scored  \
# 46                66.02                7              13           6.0
# 49                66.02                7              13           6.0
# 58                25.59                1              10           2.0
# 63                25.59                1              10           2.0
#
#    Boundary_Fours Boundary_Sixes
# 46            312             45
# 49            312             45
# 58            53+              0
# 63            53+              0

# %%
df = df.drop_duplicates()

# %%
df[df['Player'].isin(['YBK Jaiswal (IND)','DR Jardine (ENG)'])]
# Out:
#                Player Playing_Span  Matches_Played  Innings_Batted  Not_Outs  \
# 46  YBK Jaiswal (IND)    2023-2025              28              53         2
# 58   DR Jardine (ENG)    1928-1934              22              33         6
#
#     Runs_Scored Highest_Inns_Score  Batting_Average Balls_Faced  \
# 46         2511               214*            49.23        3803
# 58         1296                127            48.00       2110+
#
#     Batting_Strike_Rate  Hundreds_Scored  Fifties_Scored  Ducks_Scored  \
# 46                66.02                7              13           6.0
# 58                25.59                1              10           2.0
#
#    Boundary_Fours Boundary_Sixes
# 46            312             45
# 58            53+              0

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 58    False
# 59    False
# 60    False
# 61    False
# 62    False
# Length: 62, dtype: bool

# %%
# Split the 'Playing_Span' into separate 'Start_Year' and 'End_Year' columns
df['Playing_Span'].str.split('-',expand=True)
# Out:
#        0     1
# 0   1928  1948
# 1   2022  2025
# 2   2015  2016
# 3   1963  1970
# 4   1930  1954
# ..   ...   ...
# 58  1928  1934
# 59  2002  2014
# 60  1924  1934
# 61  1930  1938
# 62  2018  2025
#
# [62 rows x 2 columns]

# %%
df['Start_Year'] = df['Playing_Span'].str.split('-').str[0]
df['End_Year'] = df['Playing_Span'].str.split('-').str[1]

# %%
# Drop the original 'Playing_Span' column as it is now redundant
df = df.drop(['Playing_Span'], axis = 1)

# %%
df.head()
# Out:
#              Player  Matches_Played  Innings_Batted  Not_Outs  Runs_Scored  \
# 0  DG Bradman (AUS)              52              80        10         6996
# 1  PHKD Mendis (SL)              14              24         3         1316
# 2    AC Voges (AUS)              20              31         7         1485
# 3   RG Pollock (SA)              23              41         4         2256
# 4   GA Headley (WI)              22              40         4         2190
#
#   Highest_Inns_Score  Batting_Average Balls_Faced  Batting_Strike_Rate  \
# 0                334            99.94       9800+                58.60
# 1               182*            62.66        2063                63.79
# 2               269*            61.87        2667                55.68
# 3                274            60.97       1707+                54.48
# 4               270*            60.83        416+                56.00
#
#    Hundreds_Scored  Fifties_Scored  Ducks_Scored Boundary_Fours  \
# 0               29              13           7.0           626+
# 1                5               5           0.0            137
# 2                5               4           2.0            186
# 3                7              11           1.0           246+
# 4               10               5           2.0           104+
#
#   Boundary_Sixes Start_Year End_Year
# 0              6       1928     1948
# 1             24       2022     2025
# 2              5       2015     2016
# 3             11       1963     1970
# 4              1       1930     1954

# %%
# Extract 'Country' from the 'Player' name using parenthesis as a delimiter
df['Player'].str.split('(',expand = True)
# Out:
#                         0        1
# 0             DG Bradman      AUS)
# 1            PHKD Mendis       SL)
# 2               AC Voges      AUS)
# 3             RG Pollock       SA)
# 4             GA Headley       WI)
# ..                    ...      ...
# 58            DR Jardine      ENG)
# 59              GC Smith   ICC/SA)
# 60           WH Ponsford      AUS)
# 61             SJ McCabe      AUS)
# 62  Hashmatullah Shahidi      AFG)
#
# [62 rows x 2 columns]

# %%
df['Country'] = df['Player'].str.split('(').str[1]

# %%
df['Country']
# Out:
# 0        AUS)
# 1         SL)
# 2        AUS)
# 3         SA)
# 4         WI)
#        ...
# 58       ENG)
# 59    ICC/SA)
# 60       AUS)
# 61       AUS)
# 62       AFG)
# Name: Country, Length: 62, dtype: object

# %%
df['Country'] = df['Country'].str.split(')').str[0]

# %%
df['Country']
# Out:
# 0        AUS
# 1         SL
# 2        AUS
# 3         SA
# 4         WI
#        ...
# 58       ENG
# 59    ICC/SA
# 60       AUS
# 61       AUS
# 62       AFG
# Name: Country, Length: 62, dtype: object

# %%
df['Player']
# Out:
# 0               DG Bradman (AUS)
# 1               PHKD Mendis (SL)
# 2                 AC Voges (AUS)
# 3                RG Pollock (SA)
# 4                GA Headley (WI)
#                  ...
# 58              DR Jardine (ENG)
# 59             GC Smith (ICC/SA)
# 60             WH Ponsford (AUS)
# 61               SJ McCabe (AUS)
# 62    Hashmatullah Shahidi (AFG)
# Name: Player, Length: 62, dtype: object

# %%
# Clean the 'Player' name by removing the country information
df['Player'] = df['Player'].str.split('(').str[0]

# %%
df['Player']
# Out:
# 0               DG Bradman
# 1              PHKD Mendis
# 2                 AC Voges
# 3               RG Pollock
# 4               GA Headley
#               ...
# 58              DR Jardine
# 59                GC Smith
# 60             WH Ponsford
# 61               SJ McCabe
# 62    Hashmatullah Shahidi
# Name: Player, Length: 62, dtype: object

# %%
# Change Data types
df.dtypes
# Out:
# Player                  object
# Matches_Played           int64
# Innings_Batted           int64
# Not_Outs                 int64
# Runs_Scored              int64
# Highest_Inns_Score      object
# Batting_Average        float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# Hundreds_Scored          int64
# Fifties_Scored           int64
# Ducks_Scored           float64
# Boundary_Fours          object
# Boundary_Sixes          object
# Start_Year              object
# End_Year                object
# Country                 object
# dtype: object

# %%
# Clean numerical columns by removing special characters

# %%
# Remove *
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].str.split('*').str[0]

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].astype(int)

# %%
# Remove +
df['Balls_Faced'] = df['Balls_Faced'].str.split('+').str[0]

# %%
# Re-fill any potential nulls after string manipulation before conversion
df.isnull().any()
# Out:
# Player                 False
# Matches_Played         False
# Innings_Batted         False
# Not_Outs               False
# Runs_Scored            False
# Highest_Inns_Score     False
# Batting_Average        False
# Balls_Faced             True
# Batting_Strike_Rate    False
# Hundreds_Scored        False
# Fifties_Scored         False
# Ducks_Scored           False
# Boundary_Fours         False
# Boundary_Sixes         False
# Start_Year             False
# End_Year               False
# Country                False
# dtype: bool

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
#              Player  Matches_Played  Innings_Batted  Not_Outs  Runs_Scored  \
# 8        ED Weekes               48              81         5         4455
# 13      CL Walcott               44              74         7         3798
# 54  Hon.FS Jackson               20              33         4         1415
#
#     Highest_Inns_Score  Batting_Average Balls_Faced  Batting_Strike_Rate  \
# 8                  207            58.61         NaN                  0.0
# 13                 220            56.68         NaN                  0.0
# 54                 144            48.79         NaN                  0.0
#
#     Hundreds_Scored  Fifties_Scored  Ducks_Scored Boundary_Fours  \
# 8                15              19           6.0           258+
# 13               15              14           1.0           107+
# 54                5               6           3.0            51+
#
#    Boundary_Sixes Start_Year End_Year Country
# 8               2       1948     1958      WI
# 13             11       1948     1960      WI
# 54              0       1893     1905     ENG

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %%
# Convert cleaned string columns to proper integer data types
df['Balls_Faced'] = df['Balls_Faced'].astype(int)

# %%
# Remove +
df['Boundary_Fours'] = df['Boundary_Fours'].str.split('+').str[0]

# %%
df['Boundary_Fours'] = df['Boundary_Fours'].astype(int)

# %%
# Remove +
df['Boundary_Sixes'] = df['Boundary_Sixes'].str.split('+').str[0]

# %%
df['Boundary_Sixes'] = df['Boundary_Sixes'].astype(int)

# %%
df = df.astype({'Start_Year':'int','End_Year':'int'})

# %%
df.head()
# Out:
#          Player  Matches_Played  Innings_Batted  Not_Outs  Runs_Scored  \
# 0   DG Bradman               52              80        10         6996
# 1  PHKD Mendis               14              24         3         1316
# 2     AC Voges               20              31         7         1485
# 3   RG Pollock               23              41         4         2256
# 4   GA Headley               22              40         4         2190
#
#    Highest_Inns_Score  Batting_Average  Balls_Faced  Batting_Strike_Rate  \
# 0                 334            99.94         9800                58.60
# 1                 182            62.66         2063                63.79
# 2                 269            61.87         2667                55.68
# 3                 274            60.97         1707                54.48
# 4                 270            60.83          416                56.00
#
#    Hundreds_Scored  Fifties_Scored  Ducks_Scored  Boundary_Fours  \
# 0               29              13           7.0             626
# 1                5               5           0.0             137
# 2                5               4           2.0             186
# 3                7              11           1.0             246
# 4               10               5           2.0             104
#
#    Boundary_Sixes  Start_Year  End_Year Country
# 0               6        1928      1948     AUS
# 1              24        2022      2025      SL
# 2               5        2015      2016     AUS
# 3              11        1963      1970      SA
# 4               1        1930      1954      WI

# %%
df.dtypes
# Out:
# Player                  object
# Matches_Played           int64
# Innings_Batted           int64
# Not_Outs                 int64
# Runs_Scored              int64
# Highest_Inns_Score       int64
# Batting_Average        float64
# Balls_Faced              int64
# Batting_Strike_Rate    float64
# Hundreds_Scored          int64
# Fifties_Scored           int64
# Ducks_Scored           float64
# Boundary_Fours           int64
# Boundary_Sixes           int64
# Start_Year               int64
# End_Year                 int64
# Country                 object
# dtype: object

# %%
# Calculate Career Length
df['Career_Length'] = df['End_Year'] - df['Start_Year']

# %%
# Calculate the average Career Length
df['Career_Length'].mean()
# Out:
# np.float64(13.129032258064516)

# %%
# Calculate the average Batting_Strike_Rate for players who played over 10 years
df[df['Career_Length'] > 10]['Batting_Strike_Rate'].mean()
# Out:
# np.float64(47.8153488372093)

# %%
# Find number of players who played before 1960
df[df['Start_Year']<1960]['Player'].count()
# Out:
# np.int64(23)

# %%
# Max Highest_Inns_Score by country
df.groupby('Country')['Highest_Inns_Score'].max()
# Out:
# Country
# AFG        246
# AUS        380
# ENG        364
# ICC/IND    319
# ICC/PAK    329
# ICC/SA     277
# ICC/WI     400
# IND        248
# NZ         251
# PAK        313
# SA         278
# SL         374
# WI         365
# ZIM        232
# Name: Highest_Inns_Score, dtype: int64

# %%
# Hundreds_Scored and Fifties_Scored and Ducks_Scored average by country
df.groupby('Country')[['Hundreds_Scored','Fifties_Scored','Ducks_Scored']].mean()
# Out:
#          Hundreds_Scored  Fifties_Scored  Ducks_Scored
# Country
# AFG             2.000000        2.000000      0.000000
# AUS            21.600000       29.133333      8.933333
# ENG            13.615385       21.846154      4.769231
# ICC/IND        29.500000       47.500000     12.000000
# ICC/PAK        25.000000       46.000000     15.000000
# ICC/SA         36.000000       48.000000     13.500000
# ICC/WI         34.000000       48.000000     17.000000
# IND            24.000000       32.250000      8.750000
# NZ             33.000000       38.000000     11.000000
# PAK            21.250000       28.000000      9.500000
# SA              9.800000       20.200000      3.400000
# SL             22.750000       34.250000      9.250000
# WI             16.625000       25.625000      7.250000
# ZIM            12.000000       27.000000      5.000000

# %%
# Export the final cleaned and analyzed dataset to Excel without row index
df.to_excel("Cricket_Cleaned_Data.xlsx", index=False)
